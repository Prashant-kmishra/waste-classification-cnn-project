# %%
import opendatasets as od
import os

# %%
target_dir = '/Users/prashantmishra/Codebasics /Data Science /Deep Learning/Convolutional Neural Networks ( CNNs ) /AI Waste Management'

os.makedirs(target_dir, exist_ok=True)
os.chdir(target_dir)
dataset_url = "https://www.kaggle.com/datasets/techsash/waste-classification-data"
od.download(dataset_url)

data_dir = os.path.join(target_dir, 'waste-classification-data')
print(f"Dataset successfully downloaded and unzipped at: {data_dir}")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:  prashant2quant
# Your Kaggle Key:  ········
# Dataset URL: https://www.kaggle.com/datasets/techsash/waste-classification-data
# ...
# 100%|███████████████████████████████████████| 427M/427M [00:53<00:00, 8.37MB/s]
# Dataset successfully downloaded and unzipped at: /Users/prashantmishra/Codebasics /Data Science /Deep Learning/Convolutional Neural Networks ( CNNs ) /AI Waste Management/waste-classification-data
